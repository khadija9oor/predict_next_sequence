# %%
9# source text
data = """ Jack and Jill went up the hill\n
To fetch a pail of water\n
Jack fell down and broke his crown\n
And Jill came tumbling after\n """

# %% [markdown]
# #Model 1: One-Word-In, One-Word-Out Sequences
# ####We can start with a very simple model. Given one word as input, the model will learn to predict the next word in the sequence.
#
# ####The first step is to encode the text as integers. Each lowercase word in the source text is assigned a unique integer and we can convert the sequences of words to sequences of integers.
#
# ####Keras provides the Tokenizer class that can be used to perform this encoding.
#
# ####First, the Tokenizer is fit on the source text to develop the mapping from words to unique integers. Then sequences of text can be converted to sequences of integers by calling the texts to sequences() function.

# %%
from keras.preprocessing.text import Tokenizer
# integer encode text
tokenizer = Tokenizer()
tokenizer.fit_on_texts([data])
encoded = tokenizer.texts_to_sequences([data])[0]

# %% [markdown]
# ####We will need to know the size of the vocabulary later for both defining the word embedding layer in the model, and for encoding output words using a one hot encoding.
#
# ####The size of the vocabulary can be retrieved from the trained Tokenizer by accessing the word index attribute.

# %%
# determine the vocabulary size
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 22

# %% [markdown]
# ####Running this example, we can see that the size of the vocabulary is 22 words.
#
# ####We add one,because we will need to specify the integer for the largest encoded word as an array index, e.g. words encoded 1 to 21 with array indicies 0 to 21 or 22 positions.
#
# ####Next, we need to create sequences of words to fit the model with one word as input and one word as output.

# %%
#create word -> word sequences
sequences = []
for i in range(1, len(encoded)):
    sequence = encoded[i-1:i+1]
    sequences.append(sequence)
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 24

# %% [markdown]
# ###Running this piece shows that we have a total of 24 input-output pairs to train the network.
#
# ####We can then split the sequences into input (X) and output elements (y). This is straightforward as we only have two columns in the data.

# %%
#split into X and y elements
import numpy as np
import pandas as pd
sequences = np.array(sequences)
X, y = sequences[:,0],sequences[:,1]

# %% [markdown]
# ###We will fit our model to predict a probability distribution across all words in the vocabulary.
#
# ####That means that we need to turn the output element from a single integer into a one hot encoding with a 0 for every word in the vocabulary and a 1 for the actual word that the value.
#
# ###This gives the network a ground truth to aim for from which we can calculate error and update the model.
#
# ####Keras provides the to_categorical() function that we can use to convert the integer to a one hot encoding while specifying the number of classes as the vocabulary siz

# %%
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
# import plot_model from the correct module for TensorFlow 2.0 and later
from tensorflow.keras.utils import plot_model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding
# one hot encode outputs
y = to_categorical(y, num_classes=vocab_size)

# %% [markdown]
# ###We are now ready to define the neural network model.
#
# ####The model uses a 'learned word embedding' in the input layer.
#
# ####This has one real-valued vector for each word in the vocabulary, where each word vector has a specified length.
#
# ####In this case we will use a 10-dimensional projection.
#
# ####The input sequence contains a single word, therefore the input length=1.
#
# ####The model has a single hidden LSTM layer with 50 units. This is far more than is needed.
#
# ####The output layer is comprised of one neuron for each word in the vocabulary and uses a softmax activation function to ensure the output is normalized to look like a probability.

# %%
# define the model
def define_model(vocab_size):
    model = Sequential()
    model.add(Embedding(vocab_size, 10, input_length=1))
    model.add(LSTM(50))
    model.add(Dense(vocab_size, activation='softmax'))
    # compile network
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    # summarize defined model
    model.summary()
    plot_model(model, to_file='model.png', show_shapes=True)
    return model

# %% [markdown]
# ####We will use this same general network structure for each example in this tutorial, with minor changes to the learned embedding layer.
#
# ####We can compile and fit the network on the encoded text data.
#
# ####Technically, we are modeling a multiclass classification problem (predict the word in the vocabulary), therefore using the categorical cross entropy loss function.
#
# ###We use the efficientAdam implementation of gradient descent and track accuracy at the end of each epoch.
#
# ####The model is fit for 500 training epochs.
#
# ####After the model is fit, we test it by passing it a given word from the vocabulary and having the model predict the next word.
#
# ####Here we pass in "Jack" by encoding it and calling model.predict classes() to get the integer output for the predicted word. This is then looked up in the vocabulary mapping to give the associated word.

# %%
model = define_model(vocab_size) # build the model
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1, 10)             220
#
#  lstm (LSTM)                 (None, 50)                12200
#
#  dense (Dense)               (None, 22)                1122
#
# =================================================================
# Total params: 13542 (52.90 KB)
# Trainable params: 13542 (52.90 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X, y, epochs=500, verbose=2) # fit the model
# Out:
# Epoch 1/500
# 1/1 - 3s - loss: 3.0909 - accuracy: 0.0833 - 3s/epoch - 3s/step
# Epoch 2/500
# 1/1 - 0s - loss: 3.0901 - accuracy: 0.0833 - 18ms/epoch - 18ms/step
# Epoch 3/500
# 1/1 - 0s - loss: 3.0894 - accuracy: 0.2083 - 21ms/epoch - 21ms/step
# Epoch 4/500
# 1/1 - 0s - loss: 3.0886 - accuracy: 0.2083 - 32ms/epoch - 32ms/step
# Epoch 5/500
# 1/1 - 0s - loss: 3.0878 - accuracy: 0.1250 - 17ms/epoch - 17ms/step
# Epoch 6/500
# 1/1 - 0s - loss: 3.0870 - accuracy: 0.1250 - 14ms/epoch - 14ms/step
# Epoch 7/500
# 1/1 - 0s - loss: 3.0862 - accuracy: 0.1250 - 12ms/epoch - 12ms/step
# Epoch 8/500
# 1/1 - 0s - loss: 3.0854 - accuracy: 0.1250 - 12ms/epoch - 12ms/step
# Epoch 9/500
# 1/1 - 0s - loss: 3.0846 - accuracy: 0.1250 - 12ms/epoch - 12ms/step
# Epoch 10/500
# 1/1 - 0s - loss: 3.0838 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 11/500
# 1/1 - 0s - loss: 3.0830 - accuracy: 0.1250 - 14ms/epoch - 14ms/step
# Epoch 12/500
# 1/1 - 0s - loss: 3.0821 - accuracy: 0.1250 - 14ms/epoch - 14ms/step
# Epoch 13/500
# 1/1 - 0s - loss: 3.0813 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 14/500
# 1/1 - 0s - loss: 3.0804 - accuracy: 0.1250 - 29ms/epoch - 29ms/step
# Epoch 15/500
# 1/1 - 0s - loss: 3.0795 - accuracy: 0.1250 - 12ms/epoch - 12ms/step
# Epoch 16/500
# 1/1 - 0s - loss: 3.0786 - accuracy: 0.1250 - 15ms/epoch - 15ms/step
# Epoch 17/500
# 1/1 - 0s - loss: 3.0777 - accuracy: 0.1250 - 27ms/epoch - 27ms/step
# Epoch 18/500
# 1/1 - 0s - loss: 3.0767 - accuracy: 0.1250 - 18ms/epoch - 18ms/step
# Epoch 19/500
# 1/1 - 0s - loss: 3.0758 - accuracy: 0.1250 - 18ms/epoch - 18ms/step
# Epoch 20/500
# 1/1 - 0s - loss: 3.0748 - accuracy: 0.1250 - 18ms/epoch - 18ms/step
# Epoch 21/500
# 1/1 - 0s - loss: 3.0738 - accuracy: 0.1250 - 21ms/epoch - 21ms/step
# Epoch 22/500
# 1/1 - 0s - loss: 3.0727 - accuracy: 0.1250 - 36ms/epoch - 36ms/step
# Epoch 23/500
# 1/1 - 0s - loss: 3.0717 - accuracy: 0.1250 - 28ms/epoch - 28ms/step
# Epoch 24/500
# 1/1 - 0s - loss: 3.0706 - accuracy: 0.1250 - 28ms/epoch - 28ms/step
# Epoch 25/500
# 1/1 - 0s - loss: 3.0694 - accuracy: 0.1250 - 33ms/epoch - 33ms/step
# Epoch 26/500
# 1/1 - 0s - loss: 3.0683 - accuracy: 0.1250 - 30ms/epoch - 30ms/step
# Epoch 27/500
# 1/1 - 0s - loss: 3.0671 - accuracy: 0.1250 - 25ms/epoch - 25ms/step
# Epoch 28/500
# 1/1 - 0s - loss: 3.0659 - accuracy: 0.1250 - 31ms/epoch - 31ms/step
# Epoch 29/500
# 1/1 - 0s - loss: 3.0646 - accuracy: 0.1250 - 33ms/epoch - 33ms/step
# Epoch 30/500
# 1/1 - 0s - loss: 3.0633 - accuracy: 0.1250 - 14ms/epoch - 14ms/step
# Epoch 31/500
# 1/1 - 0s - loss: 3.0620 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 32/500
# 1/1 - 0s - loss: 3.0606 - accuracy: 0.1250 - 11ms/epoch - 11ms/step
# Epoch 33/500
# 1/1 - 0s - loss: 3.0592 - accuracy: 0.1250 - 12ms/epoch - 12ms/step
# Epoch 34/500
# 1/1 - 0s - loss: 3.0578 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 35/500
# 1/1 - 0s - loss: 3.0563 - accuracy: 0.1250 - 17ms/epoch - 17ms/step
# Epoch 36/500
# 1/1 - 0s - loss: 3.0548 - accuracy: 0.1250 - 14ms/epoch - 14ms/step
# Epoch 37/500
# 1/1 - 0s - loss: 3.0532 - accuracy: 0.1250 - 14ms/epoch - 14ms/step
# Epoch 38/500
# 1/1 - 0s - loss: 3.0516 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 39/500
# 1/1 - 0s - loss: 3.0499 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 40/500
# 1/1 - 0s - loss: 3.0482 - accuracy: 0.1250 - 12ms/epoch - 12ms/step
# Epoch 41/500
# 1/1 - 0s - loss: 3.0464 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 42/500
# 1/1 - 0s - loss: 3.0446 - accuracy: 0.1250 - 14ms/epoch - 14ms/step
# Epoch 43/500
# 1/1 - 0s - loss: 3.0427 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 44/500
# 1/1 - 0s - loss: 3.0408 - accuracy: 0.1250 - 14ms/epoch - 14ms/step
# Epoch 45/500
# 1/1 - 0s - loss: 3.0388 - accuracy: 0.1250 - 14ms/epoch - 14ms/step
# Epoch 46/500
# 1/1 - 0s - loss: 3.0367 - accuracy: 0.1250 - 14ms/epoch - 14ms/step
# Epoch 47/500
# 1/1 - 0s - loss: 3.0346 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 48/500
# 1/1 - 0s - loss: 3.0325 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 49/500
# 1/1 - 0s - loss: 3.0302 - accuracy: 0.1250 - 11ms/epoch - 11ms/step
# Epoch 50/500
# 1/1 - 0s - loss: 3.0279 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 51/500
# 1/1 - 0s - loss: 3.0255 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 52/500
# 1/1 - 0s - loss: 3.0231 - accuracy: 0.1250 - 15ms/epoch - 15ms/step
# Epoch 53/500
# 1/1 - 0s - loss: 3.0206 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 54/500
# 1/1 - 0s - loss: 3.0180 - accuracy: 0.1250 - 12ms/epoch - 12ms/step
# Epoch 55/500
# 1/1 - 0s - loss: 3.0153 - accuracy: 0.1250 - 12ms/epoch - 12ms/step
# Epoch 56/500
# 1/1 - 0s - loss: 3.0126 - accuracy: 0.1250 - 12ms/epoch - 12ms/step
# Epoch 57/500
# 1/1 - 0s - loss: 3.0098 - accuracy: 0.1250 - 14ms/epoch - 14ms/step
# Epoch 58/500
# 1/1 - 0s - loss: 3.0068 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 59/500
# 1/1 - 0s - loss: 3.0039 - accuracy: 0.1250 - 13ms/epoch - 13ms/step
# Epoch 60/500
# 1/1 - 0s - loss: 3.0008 - accuracy: 0.2083 - 12ms/epoch - 12ms/step
# Epoch 61/500
# 1/1 - 0s - loss: 2.9976 - accuracy: 0.2083 - 13ms/epoch - 13ms/step
# Epoch 62/500
# 1/1 - 0s - loss: 2.9943 - accuracy: 0.2083 - 16ms/epoch - 16ms/step
# Epoch 63/500
# 1/1 - 0s - loss: 2.9910 - accuracy: 0.2083 - 19ms/epoch - 19ms/step
# Epoch 64/500
# 1/1 - 0s - loss: 2.9875 - accuracy: 0.2083 - 15ms/epoch - 15ms/step
# Epoch 65/500
# 1/1 - 0s - loss: 2.9840 - accuracy: 0.2083 - 12ms/epoch - 12ms/step
# Epoch 66/500
# 1/1 - 0s - loss: 2.9804 - accuracy: 0.2083 - 11ms/epoch - 11ms/step
# Epoch 67/500
# 1/1 - 0s - loss: 2.9766 - accuracy: 0.2083 - 11ms/epoch - 11ms/step
# Epoch 68/500
# 1/1 - 0s - loss: 2.9728 - accuracy: 0.2083 - 13ms/epoch - 13ms/step
# Epoch
# 1/1 - 0s - loss: 1.8860 - accuracy: 0.4167 - 15ms/epoch - 15ms/step
# Epoch 169/500
# 1/1 - 0s - loss: 1.8710 - accuracy: 0.4583 - 16ms/epoch - 16ms/step
# Epoch 170/500
# 1/1 - 0s - loss: 1.8560 - accuracy: 0.4583 - 12ms/epoch - 12ms/step
# Epoch 171/500
# 1/1 - 0s - loss: 1.8410 - accuracy: 0.4583 - 15ms/epoch - 15ms/step
# Epoch 172/500
# 1/1 - 0s - loss: 1.8260 - accuracy: 0.5000 - 11ms/epoch - 11ms/step
# Epoch 173/500
# 1/1 - 0s - loss: 1.8111 - accuracy: 0.5000 - 13ms/epoch - 13ms/step
# Epoch 174/500
# 1/1 - 0s - loss: 1.7962 - accuracy: 0.5000 - 15ms/epoch - 15ms/step
# Epoch 175/500
# 1/1 - 0s - loss: 1.7813 - accuracy: 0.5417 - 13ms/epoch - 13ms/step
# Epoch 176/500
# 1/1 - 0s - loss: 1.7664 - accuracy: 0.5833 - 13ms/epoch - 13ms/step
# Epoch 177/500
# 1/1 - 0s - loss: 1.7516 - accuracy: 0.5833 - 15ms/epoch - 15ms/step
# Epoch 178/500
# 1/1 - 0s - loss: 1.7369 - accuracy: 0.6250 - 16ms/epoch - 16ms/step
# Epoch 179/500
# 1/1 - 0s - loss: 1.7221 - accuracy: 0.6250 - 15ms/epoch - 15ms/step
# Epoch 180/500
# 1/1 - 0s - loss: 1.7074 - accuracy: 0.6250 - 13ms/epoch - 13ms/step
# Epoch 181/500
# 1/1 - 0s - loss: 1.6928 - accuracy: 0.6250 - 11ms/epoch - 11ms/step
# Epoch 182/500
# 1/1 - 0s - loss: 1.6782 - accuracy: 0.6250 - 14ms/epoch - 14ms/step
# Epoch 183/500
# 1/1 - 0s - loss: 1.6636 - accuracy: 0.6250 - 19ms/epoch - 19ms/step
# Epoch 184/500
# 1/1 - 0s - loss: 1.6491 - accuracy: 0.6250 - 16ms/epoch - 16ms/step
# Epoch 185/500
# 1/1 - 0s - loss: 1.6346 - accuracy: 0.6250 - 22ms/epoch - 22ms/step
# Epoch 186/500
# 1/1 - 0s - loss: 1.6202 - accuracy: 0.6667 - 16ms/epoch - 16ms/step
# Epoch 187/500
# 1/1 - 0s - loss: 1.6058 - accuracy: 0.6667 - 14ms/epoch - 14ms/step
# Epoch 188/500
# 1/1 - 0s - loss: 1.5915 - accuracy: 0.6667 - 13ms/epoch - 13ms/step
# Epoch 189/500
# 1/1 - 0s - loss: 1.5772 - accuracy: 0.6667 - 13ms/epoch - 13ms/step
# Epoch 190/500
# 1/1 - 0s - loss: 1.5630 - accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 191/500
# 1/1 - 0s - loss: 1.5488 - accuracy: 0.7500 - 13ms/epoch - 13ms/step
# Epoch 192/500
# 1/1 - 0s - loss: 1.5347 - accuracy: 0.7500 - 15ms/epoch - 15ms/step
# Epoch 193/500
# 1/1 - 0s - loss: 1.5207 - accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 194/500
# 1/1 - 0s - loss: 1.5067 - accuracy: 0.7917 - 17ms/epoch - 17ms/step
# Epoch 195/500
# 1/1 - 0s - loss: 1.4927 - accuracy: 0.7917 - 13ms/epoch - 13ms/step
# Epoch 196/500
# 1/1 - 0s - loss: 1.4789 - accuracy: 0.7917 - 15ms/epoch - 15ms/step
# Epoch 197/500
# 1/1 - 0s - loss: 1.4651 - accuracy: 0.7917 - 12ms/epoch - 12ms/step
# Epoch 198/500
# 1/1 - 0s - loss: 1.4513 - accuracy: 0.7917 - 15ms/epoch - 15ms/step
# Epoch 199/500
# 1/1 - 0s - loss: 1.4377 - accuracy: 0.7917 - 13ms/epoch - 13ms/step
# Epoch 200/500
# 1/1 - 0s - loss: 1.4241 - accuracy: 0.7917 - 12ms/epoch - 12ms/step
# Epoch 201/500
# 1/1 - 0s - loss: 1.4105 - accuracy: 0.7917 - 13ms/epoch - 13ms/step
# Epoch 202/500
# 1/1 - 0s - loss: 1.3971 - accuracy: 0.7917 - 14ms/epoch - 14ms/step
# Epoch 203/500
# 1/1 - 0s - loss: 1.3837 - accuracy: 0.7917 - 14ms/epoch - 14ms/step
# Epoch 204/500
# 1/1 - 0s - loss: 1.3704 - accuracy: 0.7917 - 18ms/epoch - 18ms/step
# Epoch 205/500
# 1/1 - 0s - loss: 1.3571 - accuracy: 0.7917 - 18ms/epoch - 18ms/step
# Epoch 206/500
# 1/1 - 0s - loss: 1.3439 - accuracy: 0.7917 - 12ms/epoch - 12ms/step
# Epoch 207/500
# 1/1 - 0s - loss: 1.3309 - accuracy: 0.7917 - 14ms/epoch - 14ms/step
# Epoch 208/500
# 1/1 - 0s - loss: 1.3178 - accuracy: 0.7917 - 14ms/epoch - 14ms/step
# Epoch 209/500
# 1/1 - 0s - loss: 1.3049 - accuracy: 0.7917 - 13ms/epoch - 13ms/step
# Epoch 210/500
# 1/1 - 0s - loss: 1.2921 - accuracy: 0.7917 - 14ms/epoch - 14ms/step
# Epoch 211/500
# 1/1 - 0s - loss: 1.2793 - accuracy: 0.7917 - 14ms/epoch - 14ms/step
# Epoch 212/500
# 1/1 - 0s - loss: 1.2666 - accuracy: 0.7917 - 13ms/epoch - 13ms/step
# Epoch 213/500
# 1/1 - 0s - loss: 1.2540 - accuracy: 0.8333 - 13ms/epoch - 13ms/step
# Epoch 214/500
# 1/1 - 0s - loss: 1.2415 - accuracy: 0.8333 - 12ms/epoch - 12ms/step
# Epoch 215/500
# 1/1 - 0s - loss: 1.2290 - accuracy: 0.8333 - 13ms/epoch - 13ms/step
# Epoch 216/500
# 1/1 - 0s - loss: 1.2167 - accuracy: 0.8333 - 16ms/epoch - 16ms/step
# Epoch 217/500
# 1/1 - 0s - loss: 1.2044 - accuracy: 0.8333 - 16ms/epoch - 16ms/step
# Epoch 218/500
# 1/1 - 0s - loss: 1.1923 - accuracy: 0.8333 - 15ms/epoch - 15ms/step
# Epoch 219/500
# 1/1 - 0s - loss: 1.1802 - accuracy: 0.8333 - 12ms/epoch - 12ms/step
- accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 469/500
# 1/1 - 0s - loss: 0.2450 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 470/500
# 1/1 - 0s - loss: 0.2447 - accuracy: 0.8750 - 12ms/epoch - 12ms/step
# Epoch 471/500
# 1/1 - 0s - loss: 0.2443 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 472/500
# 1/1 - 0s - loss: 0.2439 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 473/500
# 1/1 - 0s - loss: 0.2436 - accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 474/500
# 1/1 - 0s - loss: 0.2432 - accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 475/500
# 1/1 - 0s - loss: 0.2429 - accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 476/500
# 1/1 - 0s - loss: 0.2425 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 477/500
# 1/1 - 0s - loss: 0.2422 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 478/500
# 1/1 - 0s - loss: 0.2418 - accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 479/500
# 1/1 - 0s - loss: 0.2415 - accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 480/500
# 1/1 - 0s - loss: 0.2412 - accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 481/500
# 1/1 - 0s - loss: 0.2408 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 482/500
# 1/1 - 0s - loss: 0.2405 - accuracy: 0.8750 - 10ms/epoch - 10ms/step
# Epoch 483/500
# 1/1 - 0s - loss: 0.2402 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 484/500
# 1/1 - 0s - loss: 0.2399 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 485/500
# 1/1 - 0s - loss: 0.2395 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 486/500
# 1/1 - 0s - loss: 0.2392 - accuracy: 0.8750 - 12ms/epoch - 12ms/step
# Epoch 487/500
# 1/1 - 0s - loss: 0.2389 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 488/500
# 1/1 - 0s - loss: 0.2386 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 489/500
# 1/1 - 0s - loss: 0.2383 - accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 490/500
# 1/1 - 0s - loss: 0.2380 - accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 491/500
# 1/1 - 0s - loss: 0.2377 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 492/500
# 1/1 - 0s - loss: 0.2374 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 493/500
# 1/1 - 0s - loss: 0.2371 - accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 494/500
# 1/1 - 0s - loss: 0.2368 - accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 495/500
# 1/1 - 0s - loss: 0.2366 - accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 496/500
# 1/1 - 0s - loss: 0.2363 - accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 497/500
# 1/1 - 0s - loss: 0.2360 - accuracy: 0.8750 - 8ms/epoch - 8ms/step
# Epoch 498/500
# 1/1 - 0s - loss: 0.2357 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 499/500
# 1/1 - 0s - loss: 0.2355 - accuracy: 0.8750 - 9ms/epoch - 9ms/step
# Epoch 500/500
# 1/1 - 0s - loss: 0.2352 - accuracy: 0.8750 - 8ms/epoch - 8ms/step

# %%
# evaluate
in_text = 'Jack'
print(in_text)
encoded = tokenizer.texts_to_sequences([in_text])[0]
encoded = np.array(encoded)
yhat_probs = model.predict(encoded, verbose=0)  # Get probabilities for each class
yhat = np.argmax(yhat_probs, axis=-1)  # Predict the class with highest probability
for word, index in tokenizer.word_index.items():
    if index == yhat[0]:
        print(word)
# Out:
# Jack
# and

# %% [markdown]
# ###This process could then be repeated a few times to build up a generated sequence of words.
#
# ###To make this easier, we wrap up the behavior in a function that we can call by passing in our model and the seed word.

# %%
# generate a sequence from the model
def generate_seq(model, tokenizer, seed_text, n_words):
    in_text, result = seed_text, seed_text
    # generate a fixed number of words
    for _ in range(n_words):
        # encode the text as integer
        encoded = tokenizer.texts_to_sequences([in_text])[0]
        encoded = np.array(encoded)
        # predict a word in the vocabulary
        yhat_probs = model.predict(encoded, verbose=0)  # Get probabilities for each class
        yhat = np.argmax(yhat_probs, axis=-1)  # Predict the class with highest probability
        # map predicted word index to word
        out_word = ''
        for word, index in tokenizer.word_index.items():
            if index == yhat[0]:  # Access the predicted class index
                out_word = word
                break
    # append to input
        in_text, result = out_word, result + ' ' + out_word
    return result

# %%
print(generate_seq(model, tokenizer, 'Jack', 6))
# Out:
# Jack and jill came tumbling after his
